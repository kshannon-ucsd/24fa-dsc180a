# %%
# %load_ext autoreload
# %autoreload 2

# %%
from visualization.barplot_per_disease import barplot_per_disease
from analysis.kmeans_by_age_group import kmeans_by_age_group
from analysis.kmeans_w_age import kmeans_w_age
import pandas as pd
from sklearn.cluster import KMeans
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

# %%
# You should be able to get the data by running the SQL file 'patients_w_elixhauser_age_group.sql' in the utils file in your psql session in the terminal.
patients_age_group = pd.read_csv("data/patients_w_elixhauser_age_group.csv")
patients_age_at_admission = pd.read_csv("data/patients_w_elixhauser_age.csv")

# %%
barplot_per_disease(patients_age_group)

# %%
# kmeans clustering by age_group
mdl, df = kmeans_by_age_group(patients_age_group, group_by_gender = True)

# %%
mdl, df = kmeans_w_age(patients_age_at_admission)

# %%
# If bin_age is true
df.groupby(['age_group', 'cluster']).mean()
